# %%
import random
import math
import json
import numpy as np

# %%
seed = 1 #put session number here
random.seed(seed)

# %%
base_games = [
    {
    'Type': 'Base_x',
    'Index': str(x),
    'Payoffs': {
        "U": {"L": [x, 0], "R": [0, 20]},
        "D": {"L": [0, 20], "R": [20, 0]}
        }
    } for x in [1,2,5,10,40,80]
] + [
    {
    'Type': 'Base_y',
    'Index': str(y),
    'Payoffs': {
        "U": {"L": [y, 0], "R": [0, 2]},
        "D": {"L": [0, 2], "R": [2, 0]}
        }
    } for y in [8]
]

target_games = [
    {
    'Type': 'Target',
    'Index': str(1),
    'Payoffs': {
        "U": {"L": [1, 1], "R": [1, 1]},
        "D": {"L": [1, 1], "R": [1, 1]}
        }
    },
    {
    'Type': 'Target',
    'Index': str(2),
    'Payoffs': {
        "U": {"L": [2, 2], "R": [2, 2]},
        "D": {"L": [2, 2], "R": [2, 2]}
        }
    }
]
    
dominance_games = [
    {
    'Type': 'Dominance',
    'Index': 'blue',
    'Payoffs': {
        "U": {"L": [6, 0], "R": [0, 20]},
        "D": {"L": [8, 20], "R": [20, 4]}
        }
    },
    {
    'Type': 'Dominance',
    'Index': 'red',
    'Payoffs': {
        "U": {"L": [8, 0], "R": [20, 4]},
        "D": {"L": [20, 2], "R": [12, 20]}
        }
    },
    {
    'Type': 'Dominance',
    'Index': 'both',
    'Payoffs': {
        "U": {"L": [4, 0], "R": [20, 2]},
        "D": {"L": [0, 2], "R": [2, 20]}
        }
    }
]

undercutting_games = [
    {
    'Type': 'Undercutting',
    'Index': str(1),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0], '6r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0], '6r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [10,-10], '6r': [10,-10]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [0,0], '6r': [0,0]},
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [0,0], '6r': [0,0]},
      '6b': {'1r': [0,-11], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [0,0], '6r': [-11,-11]}, 
      }
    },
    {
    'Type': 'Undercutting',
    'Index': str(2),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [0,0],  '6r': [0,0]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [10,-10],  '6r': [10,-10]}, 
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0]}, 
      '6b': {'1r': [0,-11], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [-11,-11]}, 
      }
    },
    {
    'Type': 'Undercutting',
    'Index': str(3),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [10,-10],  '6r': [10,-10], '7r': [10,-10]}, 
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '6b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '7b': {'1r': [0,-11], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [-11,-11]}, 
      }
    },
    {
    'Type': 'Undercutting',
    'Index': str(4),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0, 0], '8r': [0, 0], '9r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [10,-10],  '6r': [10,-10], '7r': [10,-10], '8r': [10,-10], '9r': [10,-10]}, 
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '6b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '7b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '8b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '9b': {'1r': [0,-11], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0, 0], '8r': [0, 0], '9r': [-11,-11]}, 
      }
    },
    {
    'Type': 'Undercutting',
    'Index': str(5),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0, 0], '8r': [0, 0], '9r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [10,-10],  '6r': [0,0], '7r': [0,0], '8r': [0,0], '9r': [0,0]}, 
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [10,-10], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '6b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [0,0],  '5r': [-10,10],  '6r': [0,0], '7r': [10,-10], '8r': [10,-10], '9r': [10,-10]}, 
      '7b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [-10,10], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '8b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [-10,10], '7r': [0,0], '8r': [0, 0], '9r': [0,0]}, 
      '9b': {'1r': [0,-11], '2r': [0,0],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [-10,10], '7r': [0,0], '8r': [0, 0], '9r': [-11,-11]}, 
      }
    },
    {
    'Type': 'Undercutting',
    'Index': str(6),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [30,-30],  '6r': [10,-10], '7r': [10,-10]}, 
      '5b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-30,30],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '6b': {'1r': [0,0], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [0,0]}, 
      '7b': {'1r': [0,-11], '2r': [0,0],  '3r': [0,0],  '4r': [-10,10],  '5r': [0,0],  '6r': [0,0], '7r': [-11,-11]}, 
      }
    }
]

actions_training_games = [
    {
    'Payoffs': {
                "U": {"L": [11, 0], "R": [50, 11]},
                "D": {"L": [50, 22], "R": [22, 0]}
                },
    'Type': 'Actions_Training',
    'Index': str(1),
    'Question_Actions': 'U,R',
    'Question_Player': 'red'
    },
    {
    'Payoffs': {
                "U": {"L": [5, 0], "R": [35, 20]},
                "D": {"L": [25, 40], "R": [10, 0]}
                },
    'Type': 'Actions_Training',
    'Index': str(2),
    'Question_Actions': 'D,R',
    'Question_Player': 'blue'
    },
]

actions_practice_games = [
    {
    'Type': 'Actions_Practice',
    'Index': str(1),
    'Payoffs': {
        "U": {"L": [11, 88], "R": [22, 66]},
        "D": {"L": [33, 77], "R": [44, 55]}
        }
    },
    {
    'Type': 'Actions_Practice',
    'Index': str(2),
    'Payoffs': {
        "U": {"L": [40, 0], "R": [0, 40]},
        "D": {"L": [0, 40], "R": [40, 0]}
        }
    } 
]


undercutting_training_games = [
    {'Type': 'Undercutting_Training',
    'Index': str(1),
     'Payoffs': {
      '1b': {'1r': [5,5], '2r': [-10,10],  '3r': [-15,15],  '4r': [-30,30]}, 
      '2b': {'1r': [10,-10], '2r': [0,0],  '3r': [0,0],  '4r': [0,-30]}, 
      '3b': {'1r': [15,-15], '2r': [0,0],  '3r': [0,0],  '4r': [5,-10]}, 
      '4b': {'1r': [30,-30], '2r': [-30,0],  '3r': [-10,5],  '4r': [-30,-30]}, 
      },
    'Question_Actions': '4b,3r',
    'Question_Player': 'red'
    }
]

undercutting_practice_games = [
    {'Type': 'Undercutting_Practice',
    'Index': str(2),
    'Payoffs': {
      '1b': {'1r': [1,1], '2r': [10,-10],  '3r': [0,0],  '4r': [0,0],  '5r': [-11,0]}, 
      '2b': {'1r': [-10,10], '2r': [0,0],  '3r': [10,-10],  '4r': [0,0],  '5r': [0,0]}, 
      '3b': {'1r': [0,0], '2r': [-10,10],  '3r': [0,0],  '4r': [10,-10],  '5r': [10,-10]}, 
      '4b': {'1r': [0,0], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [0,0]}, 
      '5b': {'1r': [0,-11], '2r': [0,0],  '3r': [-10,10],  '4r': [0,0],  '5r': [-11,-11]}, 
      }
    }
]


for games in [base_games,dominance_games,target_games]:
    for game in games:
        game['Code'] = '{}_{}'.format(game['Type'],game['Index'])
        game['Action_Rounds'] = {'blue': [], 'red': []}
        game['Belief_Rounds'] = {'blue': [], 'red': []}
    
for games in [actions_training_games,actions_practice_games,
              undercutting_training_games,undercutting_practice_games,
              undercutting_games]:
    for game in games:
        game['Code'] = '{}_{}'.format(game['Type'],game['Index'])
        game['Rounds'] = {'blue': [], 'red': []}
            
        
games = {
         game['Code']: game for game in 
         base_games 
         + dominance_games
         + target_games
         + actions_practice_games
         + actions_training_games
         + undercutting_games
         + undercutting_practice_games 
         + undercutting_training_games
        }
base_codes = [code for code in games if code.startswith('Base')]
dominance_codes = [code for code in games if code.startswith('Dominance')]
target_codes = [code for code in games if code.startswith('Target')]
undercutting_codes = [code for code in games if code.startswith('Undercutting')]
actions_training_codes = [code for code in games if code.startswith('Actions_Training')]
actions_practice_codes = [code for code in games if code.startswith('Actions_Practice')]
undercutting_training_codes = [code for code in games if code.startswith('Undercutting_Training')]
undercutting_practice_codes = [code for code in games if code.startswith('Undercutting_Practice')]

# %%
# base_games = [
#     {'Payoffs': game['payoffs'],
#     'Type': game['type'],
#     'Number': index,
#     'Code': 'B_{}_{}'.format(index),
#      'ActionRounds': [], 'BeliefRounds': []
#     } for (index,payoffs) in enumerate(base_payoffs)
# ]
# dominance_games = [
#     {'Payoffs': payoffs,
#     'Type': 'check',
#     'Number': index,
#     'Code': 'D_{}'.format(index),
#      'ActionRounds': [], 'BeliefRounds': []
#     } for (index,payoffs) in enumerate(dominance_payoffs)
# ]
# practice_games = [
#     {'Payoffs': payoffs,
#     'Type': 'practice',
#     'Number': index,
#     'Code': 'P_{}'.format(index),
#      'ActionRounds': [], 'BeliefRounds': []
#     } for (index,payoffs) in enumerate(practice_payoffs)
# ]
# undercutting_games = [
#     {'Payoffs': payoffs,
#     'Type': 'undercutting',
#     'Number': index,
#     'Code': 'U_{}'.format(index),
#     'UndercuttingRounds': []
#     } for (index,payoffs) in enumerate(undercutting_payoffs)
# ]
# undercutting_practice_games = [
#     {'Payoffs': payoffs,
#     'Type': 'undercutting_practice',
#     'Number': index,
#     'Code': 'UP_{}'.format(index),
#     'UndercuttingPracticeRounds': []
#     } for (index,payoffs) in enumerate(undercutting_practice_payoffs)
# ]

# %%
def get_buffered_sample(codes,buffer_codes):
    buffer_length = len(buffer_codes)
    non_buffer_codes = [code for code in codes if code not in buffer_codes]
    new_sample = random.sample(non_buffer_codes,buffer_length)
    reamaining_codes = [code for code in codes if code not in new_sample]
    new_sample += random.sample(reamaining_codes,len(reamaining_codes))
    return new_sample

# %%
buffer_length = 2
num_blocks = 2
block_codes = base_codes + target_codes
block_length = len(block_codes)

order_codes = random.sample(block_codes,block_length)
for block in range(num_blocks-1):
    order_codes += get_buffered_sample(block_codes,blocks[-buffer_length:])

insert_codes = ['Dominance_blue','Dominance_both','Dominance_red']
for index, code in enumerate(insert_codes):
    order_codes.insert(round((index+1)*len(order_codes+insert_codes)/(len(insert_codes)+1)),code)
    
actions_order = {}
for role in ['blue','red']:
    role_order = []
    role_codes = order_codes.copy()
    for (index, code) in enumerate(role_codes):
        rounds = [i+1 for i, x in enumerate(role_codes) if x == code]
        role_order.append({
            'Code': code,
            'Rounds': rounds,
            'Iteration': rounds.index(index+1)+1
        })
        
    actions_order[role] = role_order
    games[code]['Action_Rounds'][role] = rounds

# %%
buffer_length = 2
num_blocks = 5
block_codes = base_codes + ['self']
block_length = len(block_codes)

order_codes = random.sample(block_codes,block_length)
for block in range(num_blocks-1):
    order_codes += get_buffered_sample(block_codes,blocks[-buffer_length:])

insert_codes = ['other','other']
for index, code in enumerate(insert_codes):
    order_codes.insert(round((index+1)*len(order_codes+insert_codes)/(len(insert_codes)+1)),code)
    
beliefs_order = {}
for role in ['blue','red']:
    role_order = []
    role_codes = order_codes.copy()
    role_codes = ['Dominance_{}'.format(role) if code == 'self' else code for code in role_codes]
    other_role = 'red' if role == 'blue' else 'blue'
    role_codes = ['Dominance_{}'.format(other_role) if code == 'other' else code for code in role_codes]
    for (index, code) in enumerate(role_codes):
        rounds = [i+1 for i, x in enumerate(role_codes) if x == code]
        role_order.append({
            'Code': code,
            'Rounds': rounds,
            'Iteration': rounds.index(index+1)+1
        })
        
    beliefs_order[role] = role_order
    games[code]['Belief_Rounds'][role] = rounds

# %%
undercutting_order = []
for (index, code) in enumerate(undercutting_codes):
    rounds = [index+1]
    undercutting_order.append({
        'Code': code,
        'Rounds': rounds,
        'Iteration': 1
    })
    games[code]['UndercuttingRounds'] = rounds

# %%
practice_order = []
for (index, code) in enumerate(practice_codes):
    rounds = [index+1]
    practice_order.append({
        'Code': code,
        'Rounds': rounds,
        'Iteration': 1
    })
    games[code]['PracticeRounds'] = rounds
    
undercutting_practice_order = []
for (index, code) in enumerate(undercutting_practice_codes):
    rounds = [index+1]
    undercutting_practice_order.append({
        'Code': code,
        'Rounds': rounds,
        'Iteration': 1
    })
    games[code]['UndercuttingPracticeRounds'] = rounds 
    
training_order = []
for (index, code) in enumerate(training_codes):
    rounds = [index+1]
    training_order.append({
        'Code': code,
        'Rounds': rounds,
        'Iteration': 1
    })
    games[code]['TrainingRounds'] = rounds
    
undercutting_training_order = []
for (index, code) in enumerate(undercutting_training_codes):
    rounds = [index+1]
    undercutting_training_order.append({
        'Code': code,
        'Rounds': rounds,
        'Iteration': 1
    })
    games[code]['UndercuttingTrainingRounds'] = rounds

# %%
with open('Games/games.json','w') as f:
    json.dump(games,f)
with open('Games/action_order.json','w') as f:
    json.dump(action_order,f)
with open('Games/belief_order.json','w') as f:
    json.dump(belief_order,f)
with open('Games/undercutting_order.json','w') as f:
    json.dump(undercutting_order,f) 
with open('Games/practice_order.json','w') as f:
    json.dump(practice_order,f)  
with open('Games/undercutting_practice_order.json','w') as f:
    json.dump(undercutting_practice_order,f)
with open('Games/training_order.json','w') as f:
    json.dump(training_order,f)     
with open('Games/undercutting_training_order.json','w') as f:
    json.dump(undercutting_training_order,f)

# %%
games

# %%
action_order
